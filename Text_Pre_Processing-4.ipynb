# %% [markdown]
# **Introduction to text pre-processing**

# %% [markdown]
# Suppose you open Amazon.
#
# You search
# iPhone 15
# How does Amazon know that you're searching for a mobile?
#
# How does it understand your sentence?
#
# Can a computer actually read English?"
# (wait)
#
# Students:
# No...
#
# Some:
# Maybe...
#
# Then smile.
# Say
# Actually...
# Computers don't understand English.
#
# Write on board
#
# I Love Cricket
# Ask
# "What is this?"
#
# Students
# Sentence
#
# Now ask
# "What is this for computer?"
# Students
#
# Sentence
#
# Say
# "No."
#
# Erase.
#
# Write
# 73 32 55 18
#
# Tell
# "This is what computer actually sees."

# %% [markdown]
# "If computer cannot understand English...
#
# How is ChatGPT talking to us?"
#
# Now they'll become curious.
#
# Then explain
# Before machine understands language...
# We have to clean the text.
#
# Today's topic is
# TEXT PREPROCESSING

# %% [markdown]
# Example:
#
# Imagine...
# You hired a new employee.
#
# First day.
# You tell him
# Go to warehouse.
# Bring Apple.
#
# He returns with
# 🍎 Apple Fruit
#
# But you wanted
#
# 💻 Apple Laptop
#
# Question
# Whose mistake?
#
# Students
# Employee
# Exactly.
#
# Because we didn't give context.
#
# Computers have same problem.
#
# When we write
# Apple
#
# Computer doesn't know
#
# Fruit?
# Company?
# Logo?
# Movie?
# Music?
#
# Everything is text.
# x
# That's why preprocessing is required.

# %% [markdown]
# Step 1: Start with a Question (2 mins)
#
# Walk into the class and ask:
#
# Trainer:
# "Guys, suppose your friend sends you this message."
#
# Hiiii!!!! 😍😍😍
# I LOOOOOVE this phone!!!!!
# Visit www.amazon.in
# Call me at 9876543210
#
# Ask them:
# "Can we directly give this text to an NLP model?"
#
# Most students will say Yes or Maybe.
# Smile and say:
# "No... because computers are not smart like humans."

# %% [markdown]
# Step 2: Explain What Raw Text Means
# Say:
#
# "The text that comes directly from users, websites, emails, WhatsApp, Twitter, Instagram, Amazon reviews... is called Raw Text."
#
# Write on board
# Raw Text
# ↓
#
# Dirty
# Messy
# Unstructured
# Contains Noise
#
# Then ask:
# "What problems can you see here?"
#
# Show
# Hiiii!!!! 😍😍😍
# I LOOOOOVE this phone!!!!!
# Visit www.amazon.in
# Call me at 9876543210
#
# "Exactly.
# Before giving this to Machine Learning...
# We have to CLEAN it."

# %% [markdown]
# Cleaning Process
#
# Raw Text
#
# ↓
#
# Lowercase
#
# ↓
#
# Remove URLs
#
# ↓
#
# Remove Numbers
#
# ↓
#
# Remove Punctuation
#
# ↓
#
# Remove Emoji
#
# ↓
#
# Remove Extra Spaces
#
# ↓
#
# Clean Text

# %%
text = "Hiiii!!!! I LOOOOOVE Python 😍😍 Visit www.python.org"

# %% [markdown]
# Ask
# "What should we remove?"
# Students answer.
# Then do step by step.

# %%
# step 01: converting from capital to small
text = text.lower()
print(text)
# Out:
# hiiii!!!! i looooove python 😍😍 visit www.python.org

# %% [markdown]
# Ask
# "What changed?"
# Students
# Capital became small.

# %%
# step 02: removing URL

# %%
import re
# Python doesn't know how to search patterns by default. So we import the re library.
# re = Regular Expression

text = re.sub(r'http\S+|www\S+', '', text)
# sub means subsitute - replace something with something
# syntax : # re.sub(pattern, replacement, text)
# pattern : what we are searching for ? website, phone number, email
# '' with what you are replace '' means nothing
# https : looks for word starting with https
# \S+ means 'keep taking every character until you reach a space

print(text)
# Out:
# hiiii!!!! i looooove python 😍😍 visit

# %%
import re

# %%
test = "Hi how are you this is meeting link www.amazon.in"

# %%
test = re.sub(r'https\S+|www\S+', '', test)

# %%
test
# Out:
# 'Hi how are you this is meeting link '

# %% [markdown]
# Ask
# "Why remove website?"
# Expected answer
# Website doesn't help understand sentiment.
#
# Sentiment means the emotion, feeling, or opinion expressed in a piece of text.

# %%
# step 03: Remove punctuation

# %%
import string

text = text.translate(str.maketrans('', '', string.punctuation))
print(text)
# translate: it follows the rules which we created
# maketrnas : make - create trans - translate
# string.punctuation : This simply means: 'Give me all the punctuation symbols.' !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Out:
# hiiii i looooove python 😍😍 visit

# %%
# Ask:  what disappear here ?

# %% [markdown]
# Ask the students:
# Trainer: "What are the actual words here?"
# Students will answer:
# Hello
# How
# are
# you
# Python
# NLP
# Then ask:
# "What are these?"
# !!!
# ???
# @
# #
# .
# Students:
# "Special symbols."
# Then say:
# "Exactly! These are called punctuation marks. In many NLP tasks, they don't add useful meaning, so we remove them."

# %%
# step 04: Remove Numbers

# %%
text1 = "shaaaz 1@"

# %%
text1 = re.sub(r'\d+', '', text1)
text1 = text1.translate(str.maketrans('', '', string.punctuation))

# %%
# re.sub() → Replace or remove a pattern.
# r'' → Raw string (Python reads the pattern as it is).
# \d → Any digit (0–9).
# + → One or more digits.
# '' → Replace with nothing (remove it).
# text → The text where the replacement happens.

# %%
text1
# Out:
# 'shaaaz '

# %%
# remove extra space

# %%
text1 = " ".join(text1.split())

print(text1)
# Out:
# shaaaz

# %%
a = "shaaz.  "
b = "   mukadam"

# %%
u = " ".join(b.split())

# %%
u
# Out:
# 'mukadam'

# %%
# split() → Splits the sentence into words by removing extra spaces.
# " ".join() → Joins the words back together with one single space between them.

# %% [markdown]
# **Tokenization**

# %% [markdown]
# Good Morning Everyone
#
# Ask the class:
# Trainer: "How many words are written here?"
#
# Students:
#
# Good
# Morning
# Everyone
#
# Then ask:
# "Did anyone count the letters first?"
#
# Students:
# "No."
#
# Then ask:
# "What did your brain do first?"
#
# Students:
# "It separated the words."
# Smile and say:
#
# "Exactly! Our brain naturally separates a sentence into words. But a computer cannot do this by itself."

# %% [markdown]
# I
#
# love
#
# learning
#
# Python
#
# Ask the class:
# "What did he do?"
# Students:
# "Split the sentence."
#
# Then say:
# "Exactly! In NLP, this process is called Tokenization."

# %%
# coding

# %% [markdown]
# Write
#
# HappyBirthdayRahul
#
# Ask :
# Can you read it?:
# Yes.
#
# Now ask
# Could a computer read it?
# Not easily.
#
# Need
#
# Happy
#
# Birthday
#
# Rahul
#
# Now introduce
# Token = Small meaningful unit.

# %% [markdown]
# Write
#
# Artificial Intelligence is changing the world.
#
# Ask:
#
# Split this sentence manually.
# Expected
#
# Artificial
#
# Intelligence
#
# is
#
# changing
#
# the
#
# world
#
# Now ask
#
# "How many tokens?"
# Students answer.

# %%
# can 5 people eat a single pizza without cutting it ? No
# if we cut it into 5 pices so they can it easily so same thing we have to apply here

# %%
from nltk.tokenize import word_tokenize
import nltk
# import the NLTK (Natural Language Toolkit) library.
# from nltk.tokenize → Go to the tokenize module inside the NLTK library.
# import word_tokenize → Import the function that splits a sentence into words (tokens).

nltk.download('punkt')
nltk.download('punkt_tab')
# Download tokenizer data (only first time)



text = "I love learning NLP."


tokens = word_tokenize(text)

print(tokens)
# Out:
# ['I', 'love', 'learning', 'NLP', '.']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# But NLP models first convert text into tokens because they work word by word.

# %%
text = "Python is awesome!"

# %% [markdown]
# Sentence Tokenization

# %% [markdown]
# I love Python. I also love Machine Learning. NLP is interesting.
#
#
# "How many sentences are there?"
#
# Students
# 3
#
# Now explain:
#
# Sometimes we don't want words. We want to split a paragraph into separate sentences.

# %%
from nltk.tokenize import sent_tokenize

text = "I love Python. I also love Machine Learning. NLP is interesting."

sentences = sent_tokenize(text)

print(sentences)
# Out:
# ['I love Python.', 'I also love Machine Learning.', 'NLP is interesting.']

# %% [markdown]
# Character Tokenization

# %%
text = "Hello"

characters = list(text)

print(characters)
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %% [markdown]
# The type of tokenization depends on the problem we are solving.
#
# Real World **Example 1: **Google Search
#
#
# Best laptop under 50000
#
#
# "Does Google search character by character?"
#
# Students : "No"
#
# Does it search sentence by sentence?
# "No"
#
# It mainly focuses on
# Words
# Because
#
# Laptop
#
# Best
#
# 50000
#
# These carry the meaning.
#
# Therefore
# Google mostly uses
# Word Tokenization

# %% [markdown]
# Real World Example 2
# WhatsApp
#
# Suppose your friend sends
#
# Hello.
#
# How are you?
#
# Are you coming today?
#
#
# "How many messages are there?"
#
# Students
# 3 sentences
#
# Now suppose you are building
# AI that counts
# How many sentences people send.
#
# Will Word Tokenization help?
#
# No.
# Need
# Sentence Tokenization

# %% [markdown]
# Real World Example 3
#
# Password Checker
#
# Write
# Password@123
#
#
# "Suppose I want to check..."
#
# Does password contain
# Capital Letter?
# Number?
# Special Character?
# How should I check?
#
# Whole sentence?
# No.
#
# Words?
# No.
#
# Need
# P
#
# a
#
# s
#
# s
#
# w
#
# o
#
# r
#
# d
#
# @
#
# 1
#
# 2
#
# 3
#
# Need
# Character Tokenization.

# %% [markdown]
# Real World Example (Netflix)
#
# Tell them
# Suppose Netflix wants to know
#
# Whether a review is
#
# Positive
#
# Negative
#
# Example
#
# This movie is fantastic.
#
#
# Should Netflix analyze
# Characters?
#
# Students
# "No"
#
# Whole paragraph?
# "No"
#
# Important words
#
# movie
#
# fantastic
#
# Hence
# Word Tokenization.

# %% [markdown]
# Stopwords
#
# Learning Outcome
# By the end of the session students should know:
#
# What stopwords are
#
# Why we remove them
#
# When we should NOT remove them
#
# How to remove stopwords using NLTK
#
# Real-world applications

# %% [markdown]
# The boy is sitting on the chair.
#
# A STOPWORD :
#
# "If I remove only the important words from this sentence, which words will you keep?"
#
# Let students answer.
# Expected answers:
#
# boy
#
# sitting
#
# chair
#
# Now write:
#
# boy sitting chair
#
#
# "Can you still understand what happened?"
#
# Students will say:
# "Yes."
#
# Now ask:
# "Then why do we need words like the, is, and on?"
#
# Let them think.
# After a minute, say:
#
# "These words help us speak grammatically, but in many NLP tasks they don't add much meaning."
#
# Now reveal the topic:
# STOPWORDS

# %% [markdown]
# Real-Life Example
# Google Search
#
#
# "When you search on Google, do you type this?"
#
# What is the best mobile phone under 30000?
#
# Or do you type:
#
# best mobile phone under 30000
#
# Students usually answer:
#
# "Best mobile phone under 30000."
#
# Now ask:
# "Why didn't you type what, is, and the?"
#
# Because they don't change the search intent much.
#
# Write:
# What is the best
#
# mobile phone
# ↓
# best mobile phone
#
# Now explain:
#
# Google often focuses on the important words because they carry the main meaning.

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk

# %%
# word_tokenize() splits text into words
# stopwords gives us a ready-made list of common words

# %%
# create text

# %%
text = "The boy is playing in the garden."

# %%
# tokenize

# %%
tokens = word_tokenize(text)

print(tokens)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipykernel_1982/501238461.py in <cell line: 0>()
# ----> 1 tokens = word_tokenize(text)
#       2
#       3 print(tokens)
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#     121
#
# ...

# %% [markdown]
# which word looks important ?
#
# boy
#
# playing
#
# garden

# %%
# load stop words

# %%
stop_words = set(stopwords.words('english'))

print(stop_words)
# this will gives 100 of common english stopwords
# Out:
# {'the', 'him', 'shan', 'hasn', 'myself', 'and', 'now', 'he', 't', "they'll", "i'm", 'with', "couldn't", 'd', "aren't", 'too', 'was', "won't", "didn't", 'there', 'from', 'nor', 'she', 'on', "we'll", 'does', 'am', 'if', 'only', 'mustn', 'they', 'what', 'each', "i've", 'my', 'while', 'above', "should've", 'for', 'just', 'between', "weren't", 'where', 'about', 've', 'at', 'did', "hadn't", 'll', 'itself', "she'll", 'her', 'here', 'few', 'over', 'after', 'until', 'hadn', 'an', 'why', "isn't", 'had', "we've", 'than', 'so', 'down', "it's", 'of', 'be', 'such', 'that', 'these', 'ourselves', "mustn't", 'y', 'very', "doesn't", "they're", 'are', 'couldn', "shan't", 'any', "they'd", 'ma', "hasn't", 'have', 'shouldn', 'this', 'yours', "shouldn't", 'is', 'isn', 'will', 'how', 'needn', 'out', 'some', 'against', "we'd", 'again', 'when', "you'll", "i'd", 'hers', 'themselves', "mightn't", 'should', 'below', 'or', "you'd", 'both', 'o', 'to', "i'll", "wasn't", 'during', 'weren', 'own', 'because', 'wouldn'
# ...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# removing stop words

# %%
filtered_words = []
# Creates an empty list to store useful words.

for word in tokens:
# check every token one by one

    if word.lower() not in stop_words:
      #word.lower() : convert the word in lower case
      # why we do this lower the and The will be treated as same
      # Checks whether the word is not a stopword.
        filtered_words.append(word)
# Adds only meaningful words to the new list.
print(filtered_words)
# Out:
# ['boy', 'playing', 'garden', '.']

# %% [markdown]
# Should We Always
# Remove Stopwords?
#
# I like this movie.
#
# I do not like this movie.
#
# "Which word changes the meaning completely?"
#
# Students:
# not
#
# Now remove stopwords.
#
# like movie
# like movie
#
# Ask:
# "Are these two sentences still different?"
#
# Students:
# "No."
#
# Now explain:
# This is why we should not always remove stopwords.
#
#
# Real-World Example
# Sentiment Analysis
#
# I love this movie.
# Positive
#
# I do not love this movie.
# Negative
#
# Removing not would completely change the meaning.
#
# So for tasks like sentiment analysis, many developers keep words like not, no, and never.
#
# This is one of the most important practical points students should remember.

# %% [markdown]
# Simple Definition
#
# Sentiment Analysis is the process of finding the emotion or opinion expressed in a piece of text.
#
# In simple words:
#
# The computer tries to understand whether the text is Positive, Negative, or Neutral.
#
# Real-Life Example 1 (Amazon Reviews)
#
# Suppose a customer writes:
#
# This phone is amazing.
# Computer predicts:
# 😊 Positive
#
# Another customer writes:
# Worst phone I have ever used.
# Computer predicts:
# 😞 Negative
#
# Another customer writes:
# The phone weighs 180 grams.
# Computer predicts:
# 😐 Neutral
#
# Because this sentence only gives information and does not express an opinion.

# %% [markdown]
# "We don't remove stopwords in sentiment analysis."
#
# Instead, prove it.
#
# Sentence 1
#
# I like this movie.
#
# Ask
# "Raise your hand if this is a Positive Review."
#
# Everyone raises their hand.
# Write
# 😊 Positive
#
# Now write another sentence.
# Sentence 2
#
# I do not like this movie.
#
# Ask
# "Positive or Negative?"
# Students
# Negative
#
# Now ask
# "Which ONE word changed the entire meaning?"
#
# Students will immediately answer
#
# not
#
# Now circle not on the board.
#
# Now tell them
# "Suppose I blindly remove stopwords."
#
# Write
# I do not like this movie.
# ↓
# Remove stopwords
# ↓
# like movie
#
# Now compare.
#
# Sentence 1
#
# like movie
#
# Sentence 2
# like movie
#
# "Can you now tell which review was positive and which was negative?"
#
# Students
# No
#
# Exactly!
# Big Conclusion
#
# Tell them
# "The computer is not wrong. We removed the word that carried the emotion."
#
# Write on the board
# NOT
#
# is a Stopword
#
# BUT
#
# NOT
#
# changes meaning.
#
# Another Real Example
# (Bank)
#
# SMS
# Transaction Successful.
# Another SMS
# Transaction not Successful.
#
# Remove stopwords
# Both become
#
# Transaction Successful
# Ask
# Imagine bank software does this.
# Problem?
# Students laugh.
# Exactly.

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

text = "I do not like this movie."

tokens = word_tokenize(text)

print(tokens)
# Out:
# ['I', 'do', 'not', 'like', 'this', 'movie', '.']

# %% [markdown]
# Ask students
# Which word is important?
# Students
# NOT
# Now

# %%
stop_words = set(stopwords.words("english"))

filtered = []

for word in tokens:

    if word.lower() not in stop_words:

        filtered.append(word)

print(filtered)
# Out:
# ['like', 'movie', '.']

# %% [markdown]
# Ask
# Where is NOT?
# Students
# Gone.
# Now ask
# Meaning changed?
# YES

# %% [markdown]
# Now Show Industry Solution
# Tell students
# "Does this mean we never remove stopwords?"
# Students
# No.
# Tell them
# "We remove MOST stopwords but KEEP important ones."

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))

# %%
# remove important words from the stopword

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))

important_words = ["not", "no", "never"]

for word in important_words:
    stop_words.discard(word)   # No error if word is absent

print("not" in stop_words)
# Out:
# False

# %%
# Explain
# False means NOT is no longer treated as a stopword.

# %%
from nltk.tokenize import sent_tokenize
import nltk

# Download the tokenizer model (only the first time)
nltk.download("punkt")
nltk.download("punkt_tab")

text = """
Today I woke up early.
I went for a walk.
Then I attended my NLP class.
"""

sentences = sent_tokenize(text)

print(sentences)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['\nToday I woke up early.', 'I went for a walk.', 'Then I attended my NLP class.']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.tokenize import sent_tokenize

paragraph = """
The customer ordered a laptop online. The delivery arrived the next day. The customer left a five-star review.
"""

sentences = sent_tokenize(paragraph)

for i, sentence in enumerate(sentences, start=1):
    print(f"Sentence {i}: {sentence}")
# Out:
# Sentence 1:
# The customer ordered a laptop online.
# Sentence 2: The delivery arrived the next day.
# Sentence 3: The customer left a five-star review.

# %% [markdown]
# Write this on the board.
#
#
# Run
# Running
# Runs
# Runner
# Ran
#
# "Are these five completely different words?"
#
# "No."
#
#
# "What is common among all of them?"
#
#
# "They all talk about running."
# Exactly
#
#
# "If I search Google for 'running shoes', should Google also show results for 'run shoes'?"
# Students
# "Yes."
#
#
# "Why?"
# "Because both mean almost the same thing."
#
#
# "Exactly! But computers don't automatically know that."
#
# Today's topic:
#
# STEMMING
#
#
# Real-Life Example 1 (Google Search)
#
# Write
#
# Running Shoes
#
# "If a shop writes 'Run Shoes' and you search 'Running Shoes', should that shop disappear from the results?"
#
# "No."
#
#
# Instead of remembering
#
# Run
#
# Running
#
# Runs
#
# Runner
#
# Google stores one common form
#
# Explain
# "This process of reducing similar words to a common base is called stemming."
#
#
# Activity 1
#
# Write
#
# Play
#
# Playing
#
# Played
#
# Player
#
# Plays
#
# Ask one student
#
# "What is the common idea?"
# Students
#
# Play
#
# Now another example
#
# Read
#
# Reading
#
# Reads
#
# Reader
#
# Common idea
# Read
#
#
# "Do we really need to store all five words separately?"
#
# Students
# "No."
#
# Tell students:
# "Imagine your college has five students."
#
# Rahul
# Rahul Kumar
# R. Kumar
# Rahul K.
# Mr. Rahul
# Ask
# "Are these five different people?"
# Students
# "No."
# Exactly.
#
# Now say
# "A computer might think they are five different names."
# So we convert them to one standard representation.
#
# Similarly
#
# Running
#
# Runs
#
# Runner
#
# becomes
#
# Run
#
# Critical Thinking Question
#
# Ask
# "Suppose Amazon has one review saying 'running is fun' and another saying 'run is fun'. Should AI treat them as two completely different ideas?"
# Students
# "No."
#
# Ask
# "Then what should AI do?"
#
# Students
# "Convert both to the same root."
# Exactly.

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = [
    "running",
    "played",
    "playing",
    "studies",
    "happiness"
]

for word in words:
    print(word, " --> ", stemmer.stem(word))
# Out:
# running  -->  run
# played  -->  play
# playing  -->  play
# studies  -->  studi
# happiness  -->  happi

# %% [markdown]
# Start with an Interaction
#
# Walk into class and ask:
#
# "Suppose two teachers are checking your exam paper."
#
# Teacher A
#
# Very strict
# Follows old rules
#
# Teacher B
# More flexible
# Uses updated rules
#
#
# "Will both teachers always give the same marks?"
# Students
# "No."
#
# Now connect it.
# Porter and Snowball are like two teachers.
#
# Both try to reduce words to their root form, but they follow different sets of rules.

# %% [markdown]
# When Should We Use Porter?
#
# Use Porter when:
# You're working only with English.
#
# You want a simple, classic stemming algorithm.
# You're learning how stemming works.
#
# When Should We Use Snowball?
# Use Snowball when:
# You need support for multiple languages.

# %%
from nltk.stem import SnowballStemmer

print(SnowballStemmer.languages)
# Out:
# ('arabic', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'hungarian', 'italian', 'norwegian', 'porter', 'portuguese', 'romanian', 'russian', 'spanish', 'swedish')

# %%
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer

porter = PorterStemmer()

snowball = SnowballStemmer("english")

words = [
    "running",
    "studies",
    "playing",
    "connected",
    "connection",
    "happiness"
]

for word in words:

    print("Original :", word)

    print("Porter :", porter.stem(word))

    print("Snowball :", snowball.stem(word))

    print("-"*30)
# Out:
# Original : running
# Porter : run
# Snowball : run
# ------------------------------
# Original : studies
# Porter : studi
# Snowball : studi
# ------------------------------
# Original : playing
# Porter : play
# Snowball : play
# ------------------------------
# Original : connected
# Porter : connect
# Snowball : connect
# ------------------------------
# Original : connection
# Porter : connect
# Snowball : connect
# ------------------------------
# Original : happiness
# Porter : happi
# Snowball : happi
# ------------------------------

# %% [markdown]
# Lemmatization

# %% [markdown]
# Lemmatization is the process of converting a word into its original dictionary form (called the lemma).
#
#
# Suppose you go to a library.
# You search for:
# Running
# Will the dictionary have a page named Running?
# No.
# You'll find
# Run
#
# Running
#       │
#       ▼
# Dictionary Search
#       │
#       ▼
# Run

# %%
import pandas as pd

# %%
text = pd.read_csv('synthetic_text_cleaning_realworld.csv')

# %%
text
# Out:
#         id                                            user_id  \
# 0        1         Download now >>> free link http://spam.com
# 1        2  Stopwords should be removed from this text in ...
# 2        3                     Heeeyyy broooo wassuppp??? 😂😂😂
# 3        4           Café München is beautïful but costly $$$
# 4        5  This TEXT has MULTIPLE     spaces and --- dash...
# ...    ...                                                ...
# 1995  1996           Café München is beautïful but costly $$$
# 1996  1997           Café München is beautïful but costly $$$
# 1997  1998               Breaking news!!!! #AI #NLP @research
# 1998  1999            Working on NLP??? It's fun, isn't it???
# 1999  2000  Stopwords should be removed from this text in ...
#
#                                                username  \
# 0        Data cleaning   is      very    IMPORTANT.....
# 1                 Check this out >>> https://openai.com
# ...

# %%
text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2000 non-null   int64
#  1   user_id              2000 non-null   object
#  2   username             2000 non-null   object
#  3   email                2000 non-null   object
#  4   phone_number         2000 non-null   object
#  5   tweet_text           2000 non-null   object
#  6   post_text            2000 non-null   object
#  7   comment_text         2000 non-null   object
#  8   review_text          2000 non-null   object
#  9   bio_text             2000 non-null   object
#  10  headline             2000 non-null   object
#  11  article_text         2000 non-null   object
#  12  message_text         2000 non-null   object
#  13  chat_text            2000 non-null   object
#  14  status_text          2000 non-null   object
# ...

# %%
text["tweet_text"]
# Out:
# 0          Data cleaning   is      very    IMPORTANT.....
# 1                Café München is beautïful but costly $$$
# 2                    Breaking news!!!! #AI #NLP @research
# 3                   U r the best!! btw I'll c u 2morrow 😉
# 4                  123456789 Numbers should be removed!!!
#                               ...
# 1995                Check this out >>> https://openai.com
# 1996    Stopwords should be removed from this text in ...
# 1997              Working on NLP??? It's fun, isn't it???
# 1998              Working on NLP??? It's fun, isn't it???
# 1999                    Hello!!! This is a SAMPLE text 😊.
# Name: tweet_text, Length: 2000, dtype: object

# %% [markdown]
# **Text Data PreProcessing**

# %% [markdown]
# 1. Converting into lower case

# %%
text["tweet_text"] = text["tweet_text"].str.lower()

# %%
text['tweet_text']
# Out:
# 0          data cleaning   is      very    important.....
# 1                café münchen is beautïful but costly $$$
# 2                    breaking news!!!! #ai #nlp @research
# 3                   u r the best!! btw i'll c u 2morrow 😉
# 4                  123456789 numbers should be removed!!!
#                               ...
# 1995                check this out >>> https://openai.com
# 1996    stopwords should be removed from this text in ...
# 1997              working on nlp??? it's fun, isn't it???
# 1998              working on nlp??? it's fun, isn't it???
# 1999                    hello!!! this is a sample text 😊.
# Name: tweet_text, Length: 2000, dtype: object

# %% [markdown]
# 2. Removing all HTML tags

# %%
# beautifulsoap is used to read html and xml tag and used to remove it from text

# %%
from bs4 import BeautifulSoup

text["tweet_text"] = text["tweet_text"].apply(
    lambda x: BeautifulSoup(str(x), "html.parser").get_text()
)

print(text["tweet_text"].head())
# Out:
# 0    data cleaning   is      very    important.....
# 1          café münchen is beautïful but costly $$$
# 2              breaking news!!!! #ai #nlp @research
# 3             u r the best!! btw i'll c u 2morrow 😉
# 4            123456789 numbers should be removed!!!
# Name: tweet_text, dtype: object

# %% [markdown]
# 3. Remove URL

# %%
import re

# Function to remove URLs
def remove_url(text):
    return re.sub(r'https?://\S+|www\.\S+', '', str(text))
# matches URLS that starts with http or https
# /S means non space character

# Apply the function to the column
text["tweet_text"] = text["tweet_text"].apply(remove_url)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0    data cleaning   is      very    important
# 1           caf mnchen is beautful but costly
# 2                breaking news ai nlp research
# 3            u r the best btw ill c u 2morrow
# 4          123456789 numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 4. Removing only HashTag

# %%
import re

# Function to remove only the '#' symbol
def remove_hashtag(text):
    return re.sub(r"#", "", str(text))

# Apply the function to the column
text["tweet_text"] = text["tweet_text"].apply(remove_hashtag)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0    data cleaning   is      very    important
# 1           caf mnchen is beautful but costly
# 2                breaking news ai nlp research
# 3            u r the best btw ill c u 2morrow
# 4          123456789 numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 5. Removing Puncuation marks

# %%
import string

# Function to remove punctuation
def remove_punctuation(text):
    return str(text).translate(str.maketrans('', '', string.punctuation))

# Apply the function to the column
text["tweet_text"] = text["tweet_text"].apply(remove_punctuation)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0    data cleaning   is      very    important
# 1           caf mnchen is beautful but costly
# 2                breaking news ai nlp research
# 3            u r the best btw ill c u 2morrow
# 4          123456789 numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 6. Remove Special word

# %%
import re

# Function to remove special characters
# Keeps only alphabets (A-Z, a-z), numbers (0-9), and spaces
def remove_special_characters(text):
    return re.sub(r'[^a-zA-Z0-9\s]', '', str(text))
# [] sqauer bracket define character set
# ^ in square bracket the is not for this
# /s keeps a

# Apply the function to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(remove_special_characters)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0    data cleaning   is      very    important
# 1           caf mnchen is beautful but costly
# 2                breaking news ai nlp research
# 3            u r the best btw ill c u 2morrow
# 4          123456789 numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 7. Remove Email

# %%
import re

# Function to remove email addresses
def remove_email(text):
    return re.sub(r'\S+@\S+', '', str(text))
# \S matches any non space character . it matches anything expect space
# + means one or more
# @ matches the symbol

# Apply the function to the column
text["tweet_text"] = text["tweet_text"].apply(remove_email)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0    data cleaning   is      very    important
# 1           caf mnchen is beautful but costly
# 2                breaking news ai nlp research
# 3            u r the best btw ill c u 2morrow
# 4          123456789 numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 8. Remove Phone Number

# %%
import re

# Function to remove 10-digit phone numbers
def remove_phone_number(text):
    return re.sub(r'\b\d{10}\b', '', str(text))

# \b is boundary
# |941234567| \b is starting and \b in ending
# /d is for digits
# {10} match exactly 10 digits


# Apply the function to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(remove_phone_number)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0    data cleaning   is      very    important
# 1           caf mnchen is beautful but costly
# 2                breaking news ai nlp research
# 3            u r the best btw ill c u 2morrow
# 4          123456789 numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 9. Remove @mentions

# %%
import re

# Function to remove @mentions
def remove_mentions(text):
    return re.sub(r'@\w+', '', str(text))
    # w any word character

# Apply the function to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(remove_mentions)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0    data cleaning   is      very    important
# 1           caf mnchen is beautful but costly
# 2                breaking news ai nlp research
# 3            u r the best btw ill c u 2morrow
# 4          123456789 numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 11. Remove Emojie

# %%
pip install emoji

# %%
import emoji

# Function to remove emojis
def remove_emoji(text):
    return emoji.replace_emoji(str(text), replace='')

# Apply the function to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(remove_emoji)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0    data cleaning   is      very    important
# 1           caf mnchen is beautful but costly
# 2                breaking news ai nlp research
# 3            u r the best btw ill c u 2morrow
# 4          123456789 numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 12. Expand Chat words

# %%
# Dictionary of chat words
chat_words = {
    "u": "you",
    "r": "are",
    "btw": "by the way",
    "2morrow": "tomorrow"
}

# Function to replace chat words
def replace_chat_words(text):

    # Split the sentence into words
    words = str(text).split()

    new_words = []

    # Replace chat words if present
    for word in words:
        new_words.append(chat_words.get(word, word))

    # Join the words back into a sentence
    return " ".join(new_words)

# Apply the function to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(replace_chat_words)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0                   data cleaning is very important
# 1                 caf mnchen is beautful but costly
# 2                     breaking news ai nlp research
# 3    you are the best by the way ill c you tomorrow
# 4               123456789 numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 13. Normalize repeated letetr

# %%
import re

# Function to normalize repeated characters
# Example:
# Heeeyyy  -> Hey
# broooo   -> bro
# coooool  -> col
def normalize_repeated_characters(text):
    return re.sub(r'(.)\1{2,}', r'\1', str(text))

# Apply the function to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(normalize_repeated_characters)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0                   data cleaning is very important
# 1                 caf mnchen is beautful but costly
# 2                     breaking news ai nlp research
# 3    you are the best by the way ill c you tomorrow
# 4               123456789 numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 14. Remove accented character

# %%
# Café - Cafe

# %%
pip install unidecode

# %%
from unidecode import unidecode

# Function to remove accented characters
def remove_accented_characters(text):
    return unidecode(str(text))

# Apply the function to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(remove_accented_characters)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0                   data cleaning is very important
# 1                 caf mnchen is beautful but costly
# 2                     breaking news ai nlp research
# 3    you are the best by the way ill c you tomorrow
# 4               123456789 numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 15 Remove Special Charcacter

# %%
 import re

# Function to keep only alphabets and spaces
def remove_special_characters(text):
    return re.sub(r'[^a-zA-Z\s]', '', str(text))

# Apply the function to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(remove_special_characters)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0                   data cleaning is very important
# 1                 caf mnchen is beautful but costly
# 2                     breaking news ai nlp research
# 3    you are the best by the way ill c you tomorrow
# 4                         numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 16. Remove Extra Space

# %%
# Function to remove extra spaces
def remove_extra_spaces(text):
    return " ".join(str(text).split())

# Apply the function to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(remove_extra_spaces)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0                   data cleaning is very important
# 1                 caf mnchen is beautful but costly
# 2                     breaking news ai nlp research
# 3    you are the best by the way ill c you tomorrow
# 4                         numbers should be removed
# Name: tweet_text, dtype: object

# %% [markdown]
# 17. Tokenization

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize

# Function to tokenize each tweet
def tokenize_text(text):
    return word_tokenize(str(text))

# Apply tokenization to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(tokenize_text)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0                [data, cleaning, is, very, important]
# 1             [caf, mnchen, is, beautful, but, costly]
# 2                  [breaking, news, ai, nlp, research]
# 3    [you, are, the, best, by, the, way, ill, c, yo...
# 4                       [numbers, should, be, removed]
# Name: tweet_text, dtype: object

# %% [markdown]
# 18. Stop word remoeable

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords

# Load English stopwords
stop_words = set(stopwords.words("english"))

# Keep important words
important_words = {"not", "no", "never"}

stop_words = stop_words - important_words

# Function to remove stopwords
def remove_stopwords(words):
    filtered = []

    for word in words:
        if word.lower() not in stop_words:
            filtered.append(word)

    return filtered

# Apply to the tokenized tweet_text column
text["tweet_text"] = text["tweet_text"].apply(remove_stopwords)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0            [data, cleaning, important]
# 1        [caf, mnchen, beautful, costly]
# 2    [breaking, news, ai, nlp, research]
# 3          [best, way, ill, c, tomorrow]
# 4                     [numbers, removed]
# Name: tweet_text, dtype: object
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# 19. Stemming

# %%
from nltk.stem import PorterStemmer

# Create Porter Stemmer object
stemmer = PorterStemmer()

# Function to stem words
def stemming(words):
    stemmed = []

    for word in words:
        stemmed.append(stemmer.stem(word))

    return stemmed

# Apply stemming to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(stemming)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# 0               [data, clean, import]
# 1        [caf, mnchen, beaut, costli]
# 2    [break, news, ai, nlp, research]
# 3       [best, way, ill, c, tomorrow]
# 4                     [number, remov]
# Name: tweet_text, dtype: object

# %% [markdown]
# 20. Lemmitization

# %%
import nltk

# Download WordNet resources (run once)
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.stem import WordNetLemmatizer

# Create lemmatizer object
lemmatizer = WordNetLemmatizer()

# Function to lemmatize words
def lemmatize_words(words):
    lemmatized = []

    for word in words:
        lemmatized.append(lemmatizer.lemmatize(word))

    return lemmatized

# Apply lemmatization to the tweet_text column
text["tweet_text"] = text["tweet_text"].apply(lemmatize_words)

# Display first 5 rows
print(text["tweet_text"].head())
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# 0               [data, clean, import]
# 1        [caf, mnchen, beaut, costli]
# 2    [break, news, ai, nlp, research]
# 3       [best, way, ill, c, tomorrow]
# 4                     [number, remov]
# Name: tweet_text, dtype: object
